# %% [markdown]
# ## Initialization

# %%
import pandas as pd
import requests
import urllib
import re
import os

from bs4 import BeautifulSoup

# %% [markdown]
# ## Read dataset

# %%
if os.path.exists('dataset/kaggle_beer.csv'):
    data = pd.read_csv('dataset/kaggle_beer.csv', error_bad_lines=False)

# Subset only USA brewed beers    
data = data[data.country == 'United States']

# %%
# Print the size of the dataset
print ("Number of rows:", data.shape[0])
print ("Number of columns: ", data.shape[1])
# Out:
# Number of rows: 4588
# Number of columns:  22

# %% [markdown]
# ## Webscrapped www.beeradvocate.com to comple kaggle beer dataset

# %%
#webscrapping beeradvocate
all_beers = []
counter = 0

for index, row in data.iterrows():

    avg_score = num_ratings = style = availability = -1
    
    counter = counter + 1
    if counter%1000 == 0:
        print(counter)
    
    beer_name_og = row['beer_name']
    style_og = row['style']
    category_og = row['category']
    brewery_og = row['brewery']
    city_og = row['city']
    state_og = row['state']
    
    base_url = "https://www.beeradvocate.com"
    search_url = base_url + "/search/?qt=beer&q="
    
    if len(brewery_og.split()) > 1:
        search_beer_brewery = beer_name_og + ' ' + brewery_og.split()[0] + ' ' + brewery_og.split()[1]
    else:
        search_beer_brewery = beer_name_og + ' ' + brewery_og
    
    query_url = search_url + urllib.parse.quote(search_beer_brewery)
    page = requests.get(query_url)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    # Search result page
    query_title = soup.title
    if (query_title == "Search | BeerAdvocate"):
        first_beer_result = soup.find(id="ba-content").find_all('a')[0]
        first_beer_result_name = first_beer_result.string
        first_beer_result_relative_link = first_beer_result.get('href')

        # Beer profile page
        beer_url = base_url + first_beer_result_relative_link
        page = requests.get(beer_url)
        soup = BeautifulSoup(page.content, 'html.parser')
        
    # Get beer profile information
    try:
        ba_info = soup.find(id="info_box").text
    except:
        continue
        
    avg_score = soup.find(class_="ba-ravg").text
    num_ratings = soup.find(class_="ba-ratings").text
    style = re.search('Style: (.*)',ba_info)[1]
    avail = re.search('Availability: (.*)',ba_info)[1]
    try:
        abv = re.search(': (.*)%',soup.find(id="info_box").text)[1]
    except:
        abv = -1
    try: 
        ibu = re.search('(.*) IBU',soup.find(id="info_box").text)[1]
    except: 
        ibu = -1

    new_entry = {
        'beer_name_og' : beer_name_og,
        'avg_score' : avg_score,
        'num_of_ratings' : num_ratings,
        'style' : style,
        'avail' : avail,
        'abv' : abv,
        'ibu' : ibu,
        'style_og' : style_og,
        'category_og' : category_og,
        'brewery_og' : brewery_og,
        'city_og' : city_og,
        'state_og' : state_og     
    }
    
    all_beers.append(new_entry)
# Out:
# 1000
# 2000
# 3000
# 4000

# %% [markdown]
# ## Convert to pandas dataframe

# %%
final = pd.DataFrame(all_beers)

# %%
final.head(100)
# Out:
#       abv                  avail avg_score                  beer_name_og  \
# 0    5.00             Year-round      4.17                  Scottish Ale
# 1    5.90             Year-round      3.48           Bee Sting Honey Ale
# 2    5.00             Year-round      3.39                    Native Ale
# 3      -1               Rotating      3.33                  New Peculier
# 4    5.50             Year-round      3.72   Old Glory American Pale Ale
# 5      -1             Year-round      3.16                Canadian Light
# 6      -1               Rotating      3.04                   Honey Wheat
# 7      -1             Year-round      3.49              Stillwater Stout
# 8      -1             Year-round      3.97         Itasca Extra Pale Ale
# 9      -1             Year-round      3.56                         Light
# 10   7.80                 Winter      3.42       Hoppy Claus Holiday Ale
# 11     -1             Year-round         0             Playland Pale Ale
# 12     -1               Rotating      3.81                    Dark Wheat
# 13   5.40             Year-round      3.14                Mountain Wheat
# 14   5.10             Year-round       3.7         Moose Drool Brown Ale
# 15   4.20             Year-round      1.81        Milwaukee's Best Light
# 16   5.00                 Summer      3.69                 Whirlwind Wit
# 17   6.30             Year-round      3.77                 Bent Nail IPA
# 18   4.60             Year-round      3.73               Fat Belly Amber
# 19     -1                 Summer      4.39          WPA (Wheat Pale Ale)
# 20   4.70             Year-round      3.53                   Crystal Ale
# 21   5.10             Year-round      3.32                    Export Ale
# 22   5.20               Rotating      3.43                   Hefe Weizen
# 23   6.00  Limited (brewed once)       3.6                         Bobby
# 24   6.80  Limited (brewed once)      4.04  Auld Acquaintance Spiced Ale
# 25   5.50               Rotating         0                   Irish Stout
# 26   3.50               Rotating       3.5                 Del Rio Lager
# 27     -1             Year-round       4.1          Vashon Old Stock Ale
# 28   5.50             Year-round      3.58          Untouchable Pale Ale
# 29   5.50             Year-round      3.53                   Best Bitter
# ..    ...                    ...       ...                           ...
# 70  11.80  Limited (brewed once)      4.37                Belgian Double
# 71   5.90             Year-round      3.31                     Amber Ale
# 72   5.20               Rotating      3.72                   Spring Bock
# 73     -1               Rotating      3.74              Wooden Ships ESB
# 74   4.00             Year-round      3.37             Scorpion Pale Ale
# 75     -1             Year-round      3.65             Cat Tail Pale Ale
# 76   6.25             Year-round      3.77                    Stein Bock
# 77     -1               Rotating       3.9                    Coffee Ale
# 78   5.50                 Spring      3.73                       Maifest
# 79     -1             Year-round      3.29                    Weiss Beer
# 80   4.50             Year-round      4.11       Old Krogh Oatmeal Stout
# 81   5.90               Rotating      3.47              Indiana Pale Ale
# 82     -1               Rotating       4.2              Hard Times Lager
# 83   6.50             Year-round      3.72     Stone of Scone Scotch Ale
# 84   5.50             Year-round      3.68               Yorkshire Stout
# 85   4.80             Year-round      3.34       Ghost Pony Helles Lager
# 86     -1               Rotating      3.98              St. Paul Pilsner
# 87     -1             Year-round      3.88               Quarry Rock Red
# 88   5.70             Year-round      3.43       Collapsar Oatmeal Stout
# 89   6.20                 Winter       3.8           Red Sled Winter Ale
# 90   7.60               Rotating      3.82                   Warrior IPA
# 91   5.00             Year-round      3.73               Whitetail Wheat
# 92   4.80             Year-round      3.55        Brunette Nut Brown Ale
# 93     -1  Limited (brewed once)      4.05               Anniversary Ale
# 94   9.20               Rotating      3.76                  Roza Reserve
# 95   5.00             Year-round       3.5                 Nut Brown Ale
# 96     -1                   Fall       4.3           Peat Smoked Altbier
# 97   8.50  Limited (brewed once)      3.87        Vertical Epic 04.04.04
# 98   5.50               Rotating      3.46        Four Brothers Pale Ale
# 99   5.90             Year-round       3.5               Old English Ale
#
#                                         brewery_og             category_og  \
# 0                                  Carlyle Brewing             British Ale
# 1                             Great Divide Brewing      North American Ale
# 2                       New Glarus Brewing Company      North American Ale
# 3                    Great Dane Pub and Brewing #2             British Ale
# 4                    Great Dane Pub and Brewing #2      North American Ale
# 5                                   Courthouse Pub    North American Lager
# 6                     Great Waters Brewing Company    North American Lager
# 7   Rock Bottom Restaurant & Brewery - Minneapolis      North American Ale
# 8   Rock Bottom Restaurant & Brewery - Minneapolis             British Ale
# 9     Wild River Brewing and Pizza - Cave Junction                     NaN
# 10                           Hoppy Brewing Company             Other Style
# 11                            Beach Chalet Brewery      North American Ale
# 12                       Sierra Nevada Brewing Co.    North American Lager
# 13                            Breckenridge Brewery    North American Lager
# 14                                 Big Sky Brewing               Irish Ale
# 15                                  Miller Brewing    North American Lager
# 16                                 Victory Brewing  Belgian and French Ale
# 17                                  Red Lodge Ales      North American Ale
# 18                                 Montana Brewing      North American Ale
# 19                   Minneapolis Town Hall Brewery                     NaN
# 20                                 Big Sky Brewing                     NaN
# 21                     Shipyard Brewing - Portland      North American Ale
# 22                            Faultline Brewing #1              German Ale
# 23                                   Odell Brewing                     NaN
# 24                            Pike Pub and Brewery                     NaN
# 25                           McMenamins Mill Creek      North American Ale
# 26                            Skagit River Brewing    North American Lager
# 27                             Pacific Rim Brewing                     NaN
# 28                       Speakeasy Ales and Lagers      North American Ale
# 29                                  Dick's Brewing                     NaN
# ..                                             ...                     ...
# 70                         On Tap Bistro & Brewery                     NaN
# 71                      San Marcos Brewery & Grill      North American Ale
# 72                           Stevens Point Brewery            German Lager
# 73                   Great Dane Pub and Brewing #1                     NaN
# 74                                    Moab Brewery      North American Ale
# 75                               Backwater Brewing      North American Ale
# 76                              Stone City Brewing            German Lager
# 77                   Great Dane Pub and Brewing #2                     NaN
# 78                              Millstream Brewing            German Lager
# 79                         Crescent City Brewhouse              German Ale
# 80                  Krogh's Restaurant and Brewpub      North American Ale
# 81                  Heartland Brewery Union Square      North American Ale
# 82                                 Victory Brewing                     NaN
# 83                   Great Dane Pub and Brewing #2             British Ale
# 84                Trap Rock Restaurant and Brewery      North American Ale
# 85                Trap Rock Restaurant and Brewery                     NaN
# 86  Rock Bottom Restaurant & Brewery - Minneapolis                     NaN
# 87                 O'Hara's Brewpub and Restaurant      North American Ale
# 88                        Empyrean Brewing Company      North American Ale
# 89                        Nebraska Brewing Company                     NaN
# 90                       Left Hand Brewing Company      North American Ale
# 91                                 Montana Brewing    North American Lager
# 92                        Nebraska Brewing Company      North American Ale
# 93                                 Bandana Brewery             British Ale
# 94       Snipes Mountain Microbrewery & Restaurant                     NaN
# 95                             South Shore Brewery      North American Ale
# 96                 Three Needs Brewery and Taproom    North American Lager
# 97                               Stone Brewing Co.                     NaN
# 98                        Coronado Brewing Company      North American Ale
# 99                      San Marcos Brewery & Grill             British Ale
#
#              city_og                                                ibu  \
# 0           Rockford                                                 -1
# 1             Denver                                                 -1
# 2         New Glarus                                                 -1
# 3          Fitchburg                                                 -1
# 4          Fitchburg                                                 -1
# 5          Manitowoc                                                 -1
# 6         Saint Paul                                                 -1
# 7        Minneapolis                                                 -1
# 8        Minneapolis                                                 -1
# 9      Cave Junction                                                 -1
# 10        Sacramento                                                 -1
# 11     San Francisco                                                 -1
# 12             Chico                                                 -1
# 13            Denver                                                 -1
# 14          Missoula                                                 -1
# 15         Milwaukee                                                 -1
# 16       Downingtown                                                 -1
# 17         Red Lodge                                                 -1
# 18          Billings                                                 20
# 19       Minneapolis                                                 -1
# 20          Missoula                                                 -1
# 21          Portland                                                 -1
# 22         Sunnyvale                                                 -1
# 23      Fort Collins                                                 -1
# 24           Seattle                                                 -1
# 25        Mill Creek                                                 -1
# 26      Mount Vernon                                                 -1
# 27           Seattle                                                 -1
# 28     San Francisco                                                 -1
# 29         Centralia                                                 -1
# ..               ...                                                ...
# 70         San Diego  This is a beer for settling in. Hunkering down...
# 71        San Marcos                                                 -1
# 72     Stevens Point                                                 -1
# 73           Madison                                                 -1
# 74              Moab                                                 -1
# 75            Winona                                                 -1
# 76             Solon                                                 -1
# 77         Fitchburg                                                 -1
# 78             Amana                                                 -1
# 79       New Orleans                                                 -1
# 80            Sparta                                                 -1
# 81          New York                                                 -1
# 82       Downingtown                                                 -1
# 83         Fitchburg                                                 -1
# 84  Berkeley Heights                                                 -1
# 85  Berkeley Heights                                                 -1
# 86       Minneapolis                                                 -1
# 87       Saint Cloud                                                 -1
# 88           Lincoln                                                 22
# 89         Papillion                                                 -1
# 90          Longmont                                                 -1
# 91          Billings                                                 16
# 92         Papillion                                                 15
# 93           Mankato                                                 -1
# 94         Sunnyside                                                 73
# 95           Ashland                                                 -1
# 96        Burlington                                                 -1
# 97         Escondido                                                 -1
# 98          Coronado                                                 -1
# 99        San Marcos                                                 -1
#
#    num_of_ratings      state_og                                        style  \
# 0               7      Illinois                                 Scottish Ale
# 1              41      Colorado                      American Pale Ale (APA)
# 2              56     Wisconsin                            English Brown Ale
# 3               8     Wisconsin                           American Brown Ale
# 4              79     Wisconsin                      American Pale Ale (APA)
# 5               1     Wisconsin                         American Light Lager
# 6               3     Minnesota                      American Pale Wheat Ale
# 7              22     Minnesota                               American Stout
# 8              28     Minnesota                      American Pale Ale (APA)
# 9               9        Oregon                                German Kölsch
# 10             52    California                                Winter Warmer
# 11              0    California                      American Pale Ale (APA)
# 12              2    California                          German Dunkelweizen
# 13              6      Colorado                              Belgian Witbier
# 14          2,809       Montana                           American Brown Ale
# 15            706     Wisconsin                         American Light Lager
# 16            941  Pennsylvania                              Belgian Witbier
# 17            162       Montana                                 American IPA
# 18             22       Montana                        English Dark Mild Ale
# 19              5     Minnesota                      American Pale Ale (APA)
# 20             41       Montana                                German Kölsch
# 21            973         Maine                          American Blonde Ale
# 22              5    California                            German Hefeweizen
# 23             15      Colorado                                German Kölsch
# 24              1    Washington                                Winter Warmer
# 25              0    Washington                              Irish Dry Stout
# 26              6    Washington                         American Light Lager
# 27              5    Washington                              English Old Ale
# 28            145    California                      American Pale Ale (APA)
# 29             38    Washington                               English Bitter
# ..            ...           ...                                          ...
# 70              4    California                          American Barleywine
# 71              7    California                     American Amber / Red Ale
# 72             32     Wisconsin                                  German Bock
# 73             19     Wisconsin  English Extra Special / Strong Bitter (ESB)
# 74             42          Utah                      American Pale Ale (APA)
# 75              8     Minnesota                      American Pale Ale (APA)
# 76              4          Iowa                               German Maibock
# 77              4     Wisconsin                       Scotch Ale / Wee Heavy
# 78             35          Iowa                               German Maibock
# 79             56     Louisiana                            German Hefeweizen
# 80             19    New Jersey                        English Oatmeal Stout
# 81            104      New York                                 American IPA
# 82              3  Pennsylvania                       American Adjunct Lager
# 83             88     Wisconsin                       Scotch Ale / Wee Heavy
# 84              1    New Jersey                        English Oatmeal Stout
# 85             30    New Jersey                                German Helles
# 86              1     Minnesota                               German Pilsner
# 87              1     Minnesota                     American Amber / Red Ale
# 88             36      Nebraska                        English Oatmeal Stout
# 89              2      Nebraska                                Winter Warmer
# 90            807      Colorado                                 American IPA
# 91             21       Montana                      American Pale Wheat Ale
# 92            300      Nebraska                            English Brown Ale
# 93              2     Minnesota                        English Dark Mild Ale
# 94             30    Washington                          American Barleywine
# 95            107     Wisconsin                            English Brown Ale
# 96              1       Vermont                               German Altbier
# 97            325    California                      Belgian Strong Pale Ale
# 98             21    California                      American Pale Ale (APA)
# 99              4    California  English Extra Special / Strong Bitter (ESB)
#
#                          style_og
# 0                      Scotch Ale
# 1         American-Style Pale Ale
# 2    American-Style Amber/Red Ale
# 3                         Old Ale
# 4         American-Style Pale Ale
# 5            American-Style Lager
# 6            American-Style Lager
# 7            American-Style Stout
# 8     English-Style Pale Mild Ale
# 9                             NaN
# 10                  Winter Warmer
# 11        American-Style Pale Ale
# 12           American-Style Lager
# 13           American-Style Lager
# 14                         Porter
# 15     American-Style Light Lager
# 16            Belgian-Style White
# 17  American-Style India Pale Ale
# 18   American-Style Amber/Red Ale
# 19                            NaN
# 20                            NaN
# 21        American-Style Pale Ale
# 22  South German-Style Hefeweizen
# 23                            NaN
# 24                            NaN
# 25           American-Style Stout
# 26           American-Style Lager
# 27                            NaN
# 28        American-Style Pale Ale
# 29                            NaN
# ..                            ...
# 70                            NaN
# 71   American-Style Amber/Red Ale
# 72  Traditional German-Style Bock
# 73                            NaN
# 74        American-Style Pale Ale
# 75        American-Style Pale Ale
# 76  Traditional German-Style Bock
# 77                            NaN
# 78       German-Style Oktoberfest
# 79  South German-Style Hefeweizen
# 80           American-Style Stout
# 81        American-Style Pale Ale
# 82                            NaN
# 83                     Scotch Ale
# 84           American-Style Stout
# 85                            NaN
# 86                            NaN
# 87   American-Style Amber/Red Ale
# 88           American-Style Stout
# 89                            NaN
# 90  American-Style India Pale Ale
# 91           American-Style Lager
# 92       American-Style Brown Ale
# 93                        Old Ale
# 94                            NaN
# 95       American-Style Brown Ale
# 96           American-Style Lager
# 97                            NaN
# 98        American-Style Pale Ale
# 99                        Old Ale
#
# [100 rows x 12 columns]

# %%
# Print the size of the dataset
print ("Number of rows:", final.shape[0])
print ("Number of columns: ", final.shape[1])
# Out:
# Number of rows: 1723
# Number of columns:  12

# %% [markdown]
# ## Clean

# %%
import nltk
import string
from string import digits

# %%
remove_punctuation = str.maketrans('', '', string.punctuation)
remove_digits = str.maketrans('', '', digits)

# %%
def clean_column(df,colname):
    df[colname] = df[colname].str.translate(remove_punctuation)

# %%
ibu_filter = final.ibu.str.contains('[a-zA-Z]', regex=True)
ibu_filter = ibu_filter.fillna(False)

# %%
clean_final = final.loc[~ibu_filter]

# %%
clean_column(clean_final,'num_of_ratings')
# Out:
# C:\Users\pmann\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
clean_final['num_of_ratings'] = pd.to_numeric(clean_final['num_of_ratings'])
# Out:
# C:\Users\pmann\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# Print the size of the dataset
print ("Number of rows:", clean_final.shape[0])
print ("Number of columns: ", clean_final.shape[1])
# Out:
# Number of rows: 1705
# Number of columns:  12

# %% [markdown]
# ## Export to CSV

# %%
export_csv = clean_final.to_csv (r'dataset\beer_advocate_webscrapped.csv', index = None, header=True)
